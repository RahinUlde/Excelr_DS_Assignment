# %% [markdown]
# # Assignment 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np
import statistics as stat

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Q7

# %%
Q7 = pd.read_csv("https://raw.githubusercontent.com/RahinUlde/DataSets/main/Q7.csv")

# %%
Q7.head()
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
Q7.rename(columns={'Unnamed: 0':'Cars'}, inplace = True)

# %%
Q7.head()
# Out:
#                 Cars  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
print('Mean for points is',Q7['Points'].mean())
print('Median for points is',Q7['Points'].median())
print('Mode for points is',Q7['Points'].mode())
print('Variance for points is',Q7['Points'].var())
print('Standard Deviation for points is',Q7['Points'].std())
# Out:
# Mean for points is 3.5965625
# Median for points is 3.6950000000000003
# Mode for points is 0    3.07
# 1    3.92
# Name: Points, dtype: float64
# Variance for points is 0.28588135080645166
# Standard Deviation for points is 0.5346787360709716

# %%
print('Range of points are',Q7['Points'].max()-Q7['Points'].min())
# Out:
# Range of points are 2.17

# %%
print('Mean for score is',Q7['Score'].mean())
print('Median for score is',Q7['Score'].median())
print('Mode for score is',Q7['Score'].mode())
print('Variance for score is',Q7['Score'].var())
print('Standard Deviation for score is',Q7['Score'].std())
# Out:
# Mean for score is 3.2172500000000004
# Median for score is 3.325
# Mode for score is 0    3.44
# Name: Score, dtype: float64
# Variance for score is 0.9573789677419356
# Standard Deviation for score is 0.9784574429896967

# %%
print('Range of Score are',Q7['Score'].max()-Q7['Score'].min())
# Out:
# Range of Score are 3.9110000000000005

# %%
print('Mean for Weigh is',Q7['Weigh'].mean())
print('Median for Weigh is',Q7['Weigh'].median())
print('Mode for Weigh is',Q7['Weigh'].mode())
print('Variance for Weigh is',Q7['Weigh'].var())
print('Standard Deviation for Weigh is',Q7['Weigh'].std())
# Out:
# Mean for Weigh is 17.848750000000003
# Median for Weigh is 17.71
# Mode for Weigh is 0    17.02
# 1    18.90
# Name: Weigh, dtype: float64
# Variance for Weigh is 3.193166129032258
# Standard Deviation for Weigh is 1.7869432360968431

# %%
print('Range of Weigh are',Q7['Weigh'].max()-Q7['Weigh'].min())
# Out:
# Range of Weigh are 8.399999999999999

# %%
plt.hist(Q7["Points"], edgecolor= 'black')
# Out:
# (array([3., 8., 2., 2., 4., 6., 5., 1., 0., 1.]),
#  array([2.76 , 2.977, 3.194, 3.411, 3.628, 3.845, 4.062, 4.279, 4.496,
#         4.713, 4.93 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x = 'Points', data = Q7)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bbdc7cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bbe0d0d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bbdff510>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bbe0e590>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bbe0c510>],
#  'means': []}

# %%
plt.hist(Q7["Score"], edgecolor= 'black')
# Out:
# (array([3., 3., 3., 3., 9., 7., 1., 0., 0., 3.]),
#  array([1.513 , 1.9041, 2.2952, 2.6863, 3.0774, 3.4685, 3.8596, 4.2507,
#         4.6418, 5.0329, 5.424 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x = 'Score', data = Q7)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bbb81010>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bbbb1d10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bbbab910>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bbbb30d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bbbb1110>],
#  'means': []}

# %%
plt.hist(Q7["Weigh"], bins = 10, edgecolor= 'black')
# Out:
# (array([2., 3., 4., 8., 6., 4., 4., 0., 0., 1.]),
#  array([14.5 , 15.34, 16.18, 17.02, 17.86, 18.7 , 19.54, 20.38, 21.22,
#         22.06, 22.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x = 'Weigh', data = Q7)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bbb913d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bceb2950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bbbdb710>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bceb3dd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bbb1c810>],
#  'means': []}

# %%
plt.figure(figsize=(16,9))
plt.barh(Q7["Cars"], Q7["Score"])
plt.yticks(fontsize=14)
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.barh(Q7["Cars"], Q7["Points"])
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# # Q9

# %%
Q9a = pd.read_csv('https://raw.githubusercontent.com/RahinUlde/DataSets/main/Q9_a.csv', index_col = 0)
Q9a.head()
# Out:
#        speed  dist
# Index
# 1          4     2
# 2          4    10
# 3          7     4
# 4          7    22
# 5          8    16

# %%
print(Q9a['speed'].skew())
print(Q9a['speed'].kurt())
# Out:
# -0.11750986144663393
# -0.5089944204057617

# %%
print(Q9a['dist'].skew())
print(Q9a['dist'].kurt())
# Out:
# 0.8068949601674215
# 0.4050525816795765

# %%
Q9b = pd.read_csv('https://raw.githubusercontent.com/RahinUlde/DataSets/main/Q9_b.csv', index_col = 0)

# %%
Q9b.head()
# Out:
#            SP         WT
# 1  104.185353  28.762059
# 2  105.461264  30.466833
# 3  105.461264  30.193597
# 4  113.461264  30.632114
# 5  104.461264  29.889149

# %%
print(Q9b['SP'].skew())
print(Q9b['SP'].kurt())
# Out:
# 1.6114501961773586
# 2.9773289437871835

# %%
print(Q9b['WT'].skew())
print(Q9b['WT'].kurt())
# Out:
# -0.6147533255357768
# 0.9502914910300326

# %% [markdown]
# # Q11

# %%
sample_mean = 200
sample_std = 30
sample_size = 2000

# %%
#for 94%
stats.t.interval(0.94, df = 1999, loc = sample_mean, scale = sample_std/np.sqrt(sample_size))
# Out:
# (198.7376089443071, 201.2623910556929)

# %%
#for 98%
stats.t.interval(0.98, df = 1999, loc = sample_mean, scale = sample_std/np.sqrt(sample_size))
# Out:
# (198.4381860483216, 201.5618139516784)

# %%
#for 96%
stats.t.interval(0.96, df = 1999, loc = sample_mean, scale = sample_std/np.sqrt(sample_size))
# Out:
# (198.6214037429732, 201.3785962570268)

# %% [markdown]
# # Q12

# %%
Q12 = [34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56]

# %%
print('Mean for given Marks is',stat.mean(Q12))
# Out:
# Mean for given Marks is 41

# %%
print('Mean for given Marks is',stat.median(Q12))
# Out:
# Mean for given Marks is 40.5

# %%
print('Mean for given Marks is',stat.variance(Q12))
# Out:
# Mean for given Marks is 25.529411764705884

# %%
print('Mean for given Marks is',stat.stdev(Q12))
# Out:
# Mean for given Marks is 5.05266382858645

# %% [markdown]
# # Q20

# %%
Q20 = pd.read_csv('https://raw.githubusercontent.com/RahinUlde/DataSets/main/Cars.csv')

# %%
Q20.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
Q20['MPG'].mean()
# Out:
# 34.42207572802469

# %%
#P(MPG>38)
1-stats.norm.cdf(38,Q20['MPG'].mean(),Q20['MPG'].std())
# Out:
# 0.34759392515827137

# %%
#P(MPG<40)
stats.norm.cdf(40,Q20['MPG'].mean(),Q20['MPG'].std())
# Out:
# 0.7293498762151609

# %%
#P(20<MPG<50)
stats.norm.cdf(50,Q20['MPG'].mean(),Q20['MPG'].std())-stats.norm.cdf(20,Q20['MPG'].mean(),Q20['MPG'].std())
# Out:
# 0.8988689169682047

# %% [markdown]
# # Q21a

# %%
Q21a = pd.read_csv('https://raw.githubusercontent.com/RahinUlde/DataSets/main/Cars.csv')

# %%
Q21a.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
sns.distplot(Q21a['MPG'])
plt.show()

# %% [markdown]
# # Q21b

# %%
Q21b = pd.read_csv('https://raw.githubusercontent.com/RahinUlde/DataSets/main/wc-at.csv')

# %%
Q21b.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
sns.distplot(Q21b['Waist'])
plt.show()

# %%
sns.distplot(Q21b['AT'])
plt.show()

# %% [markdown]
# # Q22

# %%
# z value for 90% confidence interval
print('Z score for 90% Conifidence Intervla =',stats.norm.ppf(0.95))
# Out:
# Z score for 90% Conifidence Intervla = 1.6448536269514722

# %%
# z value for 94% confidence interval
print('Z score for 94% Conifidence Intervla =',stats.norm.ppf(0.97))
# Out:
# Z score for 94% Conifidence Intervla = 1.8807936081512509

# %%
# z value for 60% confidence interval
print('Z score for 60% Conifidence Intervla =',stats.norm.ppf(0.80))
# Out:
# Z score for 60% Conifidence Intervla = 0.8416212335729143

# %% [markdown]
# # Q23

# %%
# t score for 95% confidence interval
print('T score for 95% Confidence Interval =',stats.t.ppf(0.975,df=24))
# Out:
# T score for 95% Confidence Interval = 2.0638985616280205

# %%
# t value for 96% confidence interval
print('T score for 96% Confidence Inteval =',stats.t.ppf(0.98,df=24))
# Out:
# T score for 96% Confidence Inteval = 2.1715446760080677

# %%
# t value for 99% Confidence Interval
print('T score for 99% Confidence Interval =',stats.t.ppf(0.995,df=24))
# Out:
# T score for 99% Confidence Interval = 2.796939504772804

# %% [markdown]
# # Q24

# %%
samp_mean = 260
pop_mean = 270
n = 18

# %%
t_score = (260-270)/(90/np.sqrt(n))
t_score
# Out:
# -0.4714045207910317

# %%
stats.t.cdf(-0.4714045207910317, df = 17)
# Out:
# 0.32167253567098364
